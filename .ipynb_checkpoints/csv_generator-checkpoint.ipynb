# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
from glob import glob
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
working_directory = os.getcwd() + '/90kDICT32px'
working_directory
# Out:
# '/Users/jbenavidesv/Workspace/ocr_detector/90kDICT32px'

# %% [markdown]
# # All Dataset

# %%
paths = []
with open('./90kDICT32px/annotation_train.txt', 'r') as f:
    for l in f:
        components = l.split(' ')
        path = components[0][1:]
        label = path.split('_')[1]
        paths.append([label, path])

# %%
# all_train_df = pd.DataFrame(paths, columns = ['label','path'])
all_train_df = pd.read_csv('all_train.csv')

# %%
all_train_df.head()
# Out:
#    Unnamed: 0            label                                 path
# 0           0             Lube           /2425/1/115_Lube_45484.jpg
# 1           1       Spencerian     /2425/1/114_Spencerian_73323.jpg
# 2           2  accommodatingly  /2425/1/113_accommodatingly_613.jpg
# 3           3        CARPENTER      /2425/1/112_CARPENTER_11682.jpg
# 4           4    REGURGITATING  /2425/1/111_REGURGITATING_64100.jpg

# %%
all_train_df.drop(columns = ['Unnamed: 0'], inplace = True)
all_train_df.head()
# Out:
#              label                                 path
# 0             Lube           /2425/1/115_Lube_45484.jpg
# 1       Spencerian     /2425/1/114_Spencerian_73323.jpg
# 2  accommodatingly  /2425/1/113_accommodatingly_613.jpg
# 3        CARPENTER      /2425/1/112_CARPENTER_11682.jpg
# 4    REGURGITATING  /2425/1/111_REGURGITATING_64100.jpg

# %%
file_path = working_directory + all_train_df['path'][0]
img = plt.imread(file_path, format = 'CGRAY')
plt.imshow(img, cmap = 'gray')

# %%
def draw(rows, cols, df):
    _, axs = plt.subplots(rows, cols, figsize = (16,12))
    sample = df.sample(rows * cols)

    for idx, ax in enumerate(axs.flatten()):
        label, path = sample.values[idx]
        img = plt.imread(working_directory + path)
        ax.imshow(img)
        ax.set_title(label)
        ax.axis('off')

# %%
draw(5, 5, all_train_df)

# %%
# Saving dataframe locally
all_train_df.to_csv('/Users/jbenavidesv/Workspace/ocr_detector/all_train.csv')

# %%
coach_df = all_train_df.loc[all_train_df['label'].str.startswith('alba')]
len(coach_df)
# Out:
# 214

# %%
draw(5, 5, coach_df)
